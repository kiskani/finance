# %%
import sys
sys.path.insert(1, '../src')
from utils import *

# %% [markdown]
# Goal is to see how much return one would get, by buying a fixed amount of dollars SP-500 index fund every week during a specific time period.

# %%
plot_stock_price('^GSPC', start_date='2020-01-01', end_date='2020-04-24')
# Out:
# -0.3605

# %%
compare_dollar_cost_averaging_return('^GSPC', start_date='2020-01-01', end_date='2020-05-01', window_length=7)
# Out:
# (-4.26, -4.26)

# %%
plot_stock_price('^GSPC', start_date='2019-01-01', end_date='2020-05-01')
# Out:
# 0.0947

# %%
compare_dollar_cost_averaging_return('^GSPC', start_date='2019-01-01', end_date='2020-05-01', window_length=7)
# Out:
# (-2.83, -2.83)

# %%
plot_stock_price('^GSPC', start_date='2019-01-01', end_date='2020-02-10')
# Out:
# 0.2987

# %%
compare_dollar_cost_averaging_return('^GSPC', start_date='2019-01-01', end_date='2020-02-10', window_length=7)
# Out:
# (14.19, 14.19)

# %%
plot_stock_price('^GSPC', start_date='2018-05-01', end_date='2020-05-01')
# Out:
# 0.0326

# %%
compare_dollar_cost_averaging_return('^GSPC', start_date='2018-05-01', end_date='2020-05-01', window_length=7)
# Out:
# (-1.01, -0.51)

# %%
plot_stock_price('^GSPC', start_date='2017-05-01', end_date='2020-05-01')
# Out:
# 0.0582

# %%
compare_dollar_cost_averaging_return('^GSPC', start_date='2017-05-01', end_date='2020-05-01', window_length=7)
# Out:
# (2.71, 0.9)

# %%
plot_stock_price('^GSPC', start_date='2016-05-01', end_date='2020-05-01')
# Out:
# 0.0799

# %%
compare_dollar_cost_averaging_return('^GSPC', start_date='2016-05-01', end_date='2020-05-01', window_length=7)
# Out:
# (9.17, 2.22)

# %%
plot_stock_price('^GSPC', start_date='2015-05-01', end_date='2020-05-01')
# Out:
# 0.0606

# %%
compare_dollar_cost_averaging_return('^GSPC', start_date='2015-05-01', end_date='2020-05-01', window_length=7)
# Out:
# (15.22, 2.87)

# %%
plot_stock_price('^GSPC', start_date='2014-05-01', end_date='2020-05-01')
# Out:
# 0.0702

# %%
compare_dollar_cost_averaging_return('^GSPC', start_date='2014-05-01', end_date='2020-05-01', window_length=7)
# Out:
# (19.62, 3.03)

# %%
plot_stock_price('^GSPC', start_date='2013-05-01', end_date='2020-05-01')
# Out:
# 0.0865

# %%
compare_dollar_cost_averaging_return('^GSPC', start_date='2013-05-01', end_date='2020-05-01', window_length=7)
# Out:
# (25.79, 3.33)

# %%
plot_stock_price('^GSPC', start_date='2012-05-01', end_date='2020-05-01')
# Out:
# 0.0914

# %%
compare_dollar_cost_averaging_return('^GSPC', start_date='2012-05-01', end_date='2020-05-01', window_length=7)
# Out:
# (34.81, 3.8)

# %%
plot_stock_price('^GSPC', start_date='2011-05-01', end_date='2020-05-01')
# Out:
# 0.0847

# %%
compare_dollar_cost_averaging_return('^GSPC', start_date='2011-05-01', end_date='2020-05-01', window_length=7)
# Out:
# (44.4, 4.17)

# %%
plot_stock_price('^GSPC', start_date='2010-05-01', end_date='2020-05-01')
# Out:
# 0.0894

# %%
compare_dollar_cost_averaging_return('^GSPC', start_date='2010-05-01', end_date='2020-05-01', window_length=7)
# Out:
# (53.83, 4.4)

# %%
plot_stock_price('^GSPC', start_date='2009-05-01', end_date='2020-05-01')
# Out:
# 0.1123

# %%
compare_dollar_cost_averaging_return('^GSPC', start_date='2009-05-01', end_date='2020-05-01', window_length=7)
# Out:
# (64.48, 4.63)

# %%
plot_stock_price('^GSPC', start_date='2008-05-01', end_date='2020-05-01')
# Out:
# 0.0598

# %%
compare_dollar_cost_averaging_return('^GSPC', start_date='2008-05-01', end_date='2020-05-01', window_length=7)
# Out:
# (74.42, 4.74)

# %%
plot_stock_price('^GSPC', start_date='2007-05-01', end_date='2020-05-01')
# Out:
# 0.0508

# %%
compare_dollar_cost_averaging_return('^GSPC', start_date='2007-05-01', end_date='2020-05-01', window_length=7)
# Out:
# (76.11, 4.45)

# %%
plot_stock_price('^GSPC', start_date='2006-05-01', end_date='2020-05-01')
# Out:
# 0.0568

# %%
compare_dollar_cost_averaging_return('^GSPC', start_date='2006-05-01', end_date='2020-05-01', window_length=7)
# Out:
# (78.32, 4.22)

# %%
plot_stock_price('^GSPC', start_date='2005-05-01', end_date='2020-05-01')
# Out:
# 0.0611

# %%
compare_dollar_cost_averaging_return('^GSPC', start_date='2005-05-01', end_date='2020-05-01', window_length=7)
# Out:
# (81.67, 4.06)

# %%
plot_stock_price('^GSPC', start_date='2004-05-01', end_date='2020-05-01')
# Out:
# 0.0598

# %%
compare_dollar_cost_averaging_return('^GSPC', start_date='2004-05-01', end_date='2020-05-01', window_length=7)
# Out:
# (85.76, 3.95)

# %%
plot_stock_price('^GSPC', start_date='2003-05-01', end_date='2020-05-01')
# Out:
# 0.0685

# %%
compare_dollar_cost_averaging_return('^GSPC', start_date='2003-05-01', end_date='2020-05-01', window_length=7)
# Out:
# (90.76, 3.87)

# %%
plot_stock_price('^GSPC', start_date='2002-05-01', end_date='2020-05-01')
# Out:
# 0.0546

# %%
compare_dollar_cost_averaging_return('^GSPC', start_date='2002-05-01', end_date='2020-05-01', window_length=7)
# Out:
# (97.51, 3.85)

# %%
plot_stock_price('^GSPC', start_date='2001-05-01', end_date='2020-05-01')
# Out:
# 0.0432

# %%
compare_dollar_cost_averaging_return('^GSPC', start_date='2001-05-01', end_date='2020-05-01', window_length=7)
# Out:
# (100.02, 3.72)

# %%
plot_stock_price('^GSPC', start_date='2000-05-01', end_date='2020-05-01')
# Out:
# 0.0333

# %%
compare_dollar_cost_averaging_return('^GSPC', start_date='2000-05-01', end_date='2020-05-01', window_length=7)
# Out:
# (100.44, 3.54)

# %% [markdown]
# ### Bottomline

# %% [markdown]
# Weekly dollar cost averaging yearly returns:
# * 2020-2020         $\sim$          -4.26 %
# * 2019-2020         $\sim$          -2.8 %
# * 2018-2020         $\sim$          -0.51 %
# * 2017-2020         $\sim$          0.9 %
# * 2016-2020         $\sim$          2.22 %
# * 2015-2020         $\sim$          2.87 %
# * 2014-2020         $\sim$          3.03 %
# * 2013-2020         $\sim$          3.33 %
# * 2012-2020         $\sim$          3.80 %
# * 2011-2020         $\sim$          4.17 %
# * 2010-2020         $\sim$          4.40 %
# * 2009-2020         $\sim$          4.63 %
# * 2008-2020         $\sim$          4.74 %
# * 2007-2020         $\sim$          4.45 %
# * 2006-2020         $\sim$          4.22 %
# * 2005-2020         $\sim$          4.06 %
# * 2004-2020         $\sim$          3.95 %
# * 2003-2020         $\sim$          3.87 %
# * 2002-2020         $\sim$          3.85 %
# * 2001-2020         $\sim$          3.72 %
# * 2000-2020         $\sim$          3.54 %
